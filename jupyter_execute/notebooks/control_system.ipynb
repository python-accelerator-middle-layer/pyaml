# %% [markdown]
# # Control System set up

# %% [markdown]
# The control system interface is in a separated package from pyaml
#
# pyaml itself: \
# pip install accelerator-middle-layer
#
# tango interface to pyaml: \
# pip install tango-pyaml
#
# ophyd-asynch interface to pyaml: \
# pip install pyaml-oa-cs
#
# If the above packages are installed the examples below will work
#
# Different accelerators, with different magnet names can operate with their own control system within the same script

# %%
from pyaml.accelerator import Accelerator

# %% [markdown]
# Assuming these lines are present in ../../tests/config/EBSTune_TANGO.yaml
# ```
# type: pyaml.accelerator
# name: sr
# energy: 6e9
# controls:
#   - type: tango.pyaml.controlsystem
#       tango_host: ebs-simu-3:10000
#       name: live
# ...
# powerconverter:
#       type: tango.pyaml.attribute
# ...
# tune_h:
#     type: tango.pyaml.attribute_read_only
# ...
# ```

# %%
# work with TANGO
# SR_Tango: Accelerator = Accelerator.load("../../tests/config/EBSTune.yaml")

# %% [markdown]
# Assuming these lines are present in ../../tests/config/EBSTuneOA.yaml
# ```
# type: pyaml.accelerator
# name: sr
# energy: 6e9
# controls:
#   - type: pyaml-cs-oa.pyaml.controlsystem
#       name: live
# ...
#  powerconverter:
#       type: pyaml_cs_oa.tangoRW
# ...
#  tune_h:
#     type: pyaml_cs_oa.tangoR
# ```

# %%
# work with Ophyd-Asynch - tango
SR_OphydAsynch_Tango: Accelerator = Accelerator.load(
    "../../tests/config/EBSTuneOATango.yaml"
)
# Out:
# ---------------------------------------------------------------------------
# PyAMLConfigException                      Traceback (most recent call last)
# Cell In[3], line 2
#       1 # work with Ophyd-Asynch - tango
# ----> 2 SR_OphydAsynch_Tango: Accelerator = Accelerator.load(
#       3     "../../tests/config/EBSTuneOATango.yaml"
#       4 )
#
# File /opt/hostedtoolcache/Python/3.14.2/x64/lib/python3.14/site-packages/pyaml/accelerator.py:173, in Accelerator.load(filename, use_fast_loader, ignore_external)
#     171 set_root_folder(rootfolder)
#     172 config_dict = load(os.path.basename(filename), None, use_fast_loader)
# --> 173 return Accelerator.from_dict(config_dict)
#
# File /opt/hostedtoolcache/Python/3.14.2/x64/lib/python3.14/site-packages/pyaml/accelerator.py:143, in Accelerator.from_dict(config_dict, ignore_external)
#     140 if ignore_external:
#     141     # control systems are external, so remove controls field
#     142     config_dict.pop("controls", None)
# --> 143 return Factory.depth_first_build(config_dict, ignore_external)
#
# File /opt/hostedtoolcache/Python/3.14.2/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:175, in PyAMLFactory.depth_first_build(self, d, ignore_external)
#     173 if not key == "__fieldlocations__":
#     174     if isinstance(value, dict) or isinstance(value, list):
# --> 175         obj = self.depth_first_build(value, ignore_external)
#     176         # Replace the inner dict by the object itself
#     177         d[key] = obj
#
# File /opt/hostedtoolcache/Python/3.14.2/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:165, in PyAMLFactory.depth_first_build(self, d, ignore_external)
#     163 for _index, e in enumerate(d):
#     164     if isinstance(e, dict) or isinstance(e, list):
# --> 165         obj = self.depth_first_build(e, ignore_external)
#     166         l.append(obj)
#     167     else:
#
# File /opt/hostedtoolcache/Python/3.14.2/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:180, in PyAMLFactory.depth_first_build(self, d, ignore_external)
#     177                 d[key] = obj
#     179     # We are now on leaf (no nested object), we can construct
# --> 180     return self.build_object(d, ignore_external)
#     182 raise PyAMLConfigException(
#     183     "Unexpected element found. 'dict' or 'list' expected "
#     184     "but got '{d.__class__.__name__}'"
#     185 )
#
# File /opt/hostedtoolcache/Python/3.14.2/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:95, in PyAMLFactory.build_object(self, d, ignore_external)
#      92 except ModuleNotFoundError as ex:
#      93     if not ignore_external:
#      94         # Discard module not found stack trace
# ---> 95         raise PyAMLConfigException(
#      96             "Module referenced in type cannot be found:"
#      97             + f"'{type_str}' {location_str}"
#      98         ) from None
#      99     else:
#     100         return None
#
# PyAMLConfigException: Module referenced in type cannot be found:'pyaml_cs_oa.controlsystem' /home/runner/work/pyaml/pyaml/tests/config/EBSTuneOATango.yaml at line 10, column 5.

# %% [markdown]
# Assuming these lines are present in ../../tests/config/EBSTuneOAEpics.yaml
# ```
# type: pyaml.accelerator
# name: sr
# energy: 6e9
# controls:
#   - type: pyaml-cs-oa.pyaml.controlsystem
#       name: live
# ...
#  powerconverter:
#       type: pyaml_cs_oa.epicsRW
# ...
#  tune_h:
#     type: pyaml_cs_oa.epicsR
# ```

# %%
# work with Ophyd-Asynch - tango
# SR_OphydAsynch_Epics: Accelerator = Accelerator.load(
#     "../../tests/config/EBSTuneOAEpics.yaml"
# )
