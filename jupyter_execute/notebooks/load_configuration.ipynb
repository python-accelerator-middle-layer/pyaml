# %% [markdown]
# # Configuration

# %%
from pyaml.accelerator import Accelerator

SR: Accelerator = Accelerator.load("../../tests/config/EBSTune.yaml")
# Out:
# ---------------------------------------------------------------------------
# PyAMLConfigException                      Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pyaml.accelerator import Accelerator
#       2
# ----> 3 SR: Accelerator = Accelerator.load("../../tests/config/EBSTune.yaml")
#
# File /opt/hostedtoolcache/Python/3.14.7/x64/lib/python3.14/site-packages/pyaml/accelerator.py:339, in Accelerator.load(filename, include_locations, ignore_external, validate)
#     334 except UnsupportedConfigurationRootError as ex:
#     335     raise PyAMLConfigException(
#     336         "Accelerator.load() expects a 'pyaml.accelerator' root configuration. "
#     337         "Use the factory APIs to build sub-elements directly."
#     338     ) from ex
# --> 339 return manager.build(ignore_external=ignore_external, validate=validate)
#
# File /opt/hostedtoolcache/Python/3.14.7/x64/lib/python3.14/site-packages/pyaml/configuration/manager.py:506, in ConfigurationManager.build(self, ignore_external, validate)
#     504     ROOT.set(self._build_root)
#     505 snapshot = ConfigurationManager.strip_runtime_internal_metadata(self._snapshot(include_internal_metadata=True))
# --> 506 return Accelerator.from_dict(snapshot, ignore_external=ignore_external, validate=validate)
#
# File /opt/hostedtoolcache/Python/3.14.7/x64/lib/python3.14/site-packages/pyaml/accelerator.py:297, in Accelerator.from_dict(config_dict, ignore_external, validate)
#     295 # Ensure factory is clean before building a new accelerator
#     296 Factory.clear()
# --> 297 return Factory.build(config_dict, ignore_external)
#
# File /opt/hostedtoolcache/Python/3.14.7/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:256, in PyAMLFactory.build(self, data, ignore_external)
#     253 if not isinstance(data, (dict, list)):
#     254     raise PyAMLConfigException(f"Unexpected element found. Expected 'dict' or 'list' but got '{type(data).__name__}'")
# --> 256 return self._build(data, ignore_external)
#
# File /opt/hostedtoolcache/Python/3.14.7/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:263, in PyAMLFactory._build(self, value, ignore_external)
#     260     return self._build_list(value, ignore_external)
#     262 if isinstance(value, dict):
# --> 263     return self._build_dict(value, ignore_external)
#     265 return value
#
# File /opt/hostedtoolcache/Python/3.14.7/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:272, in PyAMLFactory._build_dict(self, data, ignore_external)
#     270 def _build_dict(self, data: dict, ignore_external: bool = False):
#     271     if any(key in data for key in BUILD_KEYS):
# --> 272         return self._build_object(data, ignore_external)
#     274     return {key: self._build(value, ignore_external) for key, value in data.items()}
#
# File /opt/hostedtoolcache/Python/3.14.7/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:281, in PyAMLFactory._build_object(self, data, ignore_external)
#     278 if build_info is None:
#     279     return None
# --> 281 config = {key: self._build(value, ignore_external) for key, value in build_info.config.items()}
#     283 if build_info.config_cls is not None:
#     284     try:
#
# File /opt/hostedtoolcache/Python/3.14.7/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:260, in PyAMLFactory._build(self, value, ignore_external)
#     258 def _build(self, value: Any, ignore_external: bool = False):
#     259     if isinstance(value, list):
# --> 260         return self._build_list(value, ignore_external)
#     262     if isinstance(value, dict):
#     263         return self._build_dict(value, ignore_external)
#
# File /opt/hostedtoolcache/Python/3.14.7/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:268, in PyAMLFactory._build_list(self, items, ignore_external)
#     267 def _build_list(self, items: list[Any], ignore_external: bool = False):
# --> 268     return [self._build(item, ignore_external) for item in items]
#
# File /opt/hostedtoolcache/Python/3.14.7/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:263, in PyAMLFactory._build(self, value, ignore_external)
#     260     return self._build_list(value, ignore_external)
#     262 if isinstance(value, dict):
# --> 263     return self._build_dict(value, ignore_external)
#     265 return value
#
# File /opt/hostedtoolcache/Python/3.14.7/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:272, in PyAMLFactory._build_dict(self, data, ignore_external)
#     270 def _build_dict(self, data: dict, ignore_external: bool = False):
#     271     if any(key in data for key in BUILD_KEYS):
# --> 272         return self._build_object(data, ignore_external)
#     274     return {key: self._build(value, ignore_external) for key, value in data.items()}
#
# File /opt/hostedtoolcache/Python/3.14.7/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:277, in PyAMLFactory._build_object(self, data, ignore_external)
#     276 def _build_object(self, data: dict, ignore_external: bool = False):
# --> 277     build_info = _resolve_build_info(data, ignore_external)
#     278     if build_info is None:
#     279         return None
#
# File /opt/hostedtoolcache/Python/3.14.7/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:196, in _resolve_build_info(data, ignore_external)
#     189 if LEGACY_KEY in config:
#     190     # Legacy module/class format:
#     191     #   type: some.module
#     192     #   class: MyClass        (optional; otherwise PYAMLCLASS is used)
#     194     module_path = config.pop(LEGACY_KEY, None)
# --> 196     module = _import_module(module_path, ignore_external)
#     197     if module is None:
#     198         return None
#
# File /opt/hostedtoolcache/Python/3.14.7/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:172, in _import_module(module_path, ignore_external)
#     170 if ignore_external:
#     171     return None
# --> 172 raise PyAMLConfigException(f"Module '{module_path}' cannot be found: {exc}") from None
#
# PyAMLConfigException: Module 'tango.pyaml.controlsystem' cannot be found: No module named 'tango'

# %% [markdown]
# pyaml/tests/config/EBSTune.yaml is an example pyAML yaml configuration file that defines:
# - a 6GeV Storage ring with
#   - 1 array (family) of quadrupoles used for tune correction
#   - 1 tune device
#   - controlled by Tango
#   - simulated with AT
#
# It looks like this:
#
# ```
# type: pyaml.accelerator
# name: sr
# energy: 6e9
# simulators:
#   - type: pyaml.lattice.simulator
#     lattice: sr/lattices/ebs.mat
#     name: design
# controls:
#   - type: tango.pyaml.controlsystem
#     tango_host: ebs-simu-3:10000
#     name: live
#
# data_folder: /data/store
#   arrays:
#     - type: pyaml.arrays.magnet
#       name: QForTune
#       elements:
#         - QD2A-C03
#         - QD2E-C04
#         - QD2A-C05
#         - ...
#   devices:
#   - type: pyaml.magnet.quadrupole
#     name: QD2A-C03
#     model:
#       type: pyaml.magnet.linear_model
#       calibration_factor: 1.002096389
#       crosstalk: 0.99912
#       curve:
#         type: pyaml.configuration.csvcurve
#         file: sr/magnet_models/QD2_strength.csv
#       unit: 1/m
#       powerconverter:
#         type: tango.pyaml.attribute
#         attribute: srmag/vps-qd2/c03-a/current
#         unit: A
#   - ...
#   - ...
#   - ...
#   - type: pyaml.diagnostics.tune_monitor
#     name: BETATRON_TUNE
#     tune_h:
#       type: tango.pyaml.attribute_read_only
#       attribute: srdiag/tune/tune_h
#       unit: mm
#     tune_v:
#       type: tango.pyaml.attribute_read_only
#       attribute: srdiag/tune/tune_v
#       unit: mm
# ```
