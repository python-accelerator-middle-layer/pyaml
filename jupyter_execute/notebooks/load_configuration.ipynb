# %% [markdown]
# # Configuration

# %%
from pyaml.accelerator import Accelerator

SR: Accelerator = Accelerator.load("../../tests/config/EBSTune.yaml")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pyaml.accelerator import Accelerator
#       3 SR: Accelerator = Accelerator.load("../../tests/config/EBSTune.yaml")
#
# File /opt/hostedtoolcache/Python/3.14.2/x64/lib/python3.14/site-packages/pyaml/accelerator.py:14
#      12 from .configuration.factory import Factory
#      13 from .configuration.fileloader import load, set_root_folder
# ---> 14 from .control.controlsystem import ControlSystem
#      15 from .lattice.simulator import Simulator
#      17 # Define the main class name for this module
#
# File /opt/hostedtoolcache/Python/3.14.2/x64/lib/python3.14/site-packages/pyaml/control/controlsystem.py:30
#      28 from ..rf.rf_plant import RFPlant, RWTotalVoltage
#      29 from ..rf.rf_transmitter import RFTransmitter
# ---> 30 from ..tuning_tools.orbit import Orbit
#      31 from ..tuning_tools.tune import Tune
#      32 from .deviceaccess import DeviceAccess
#
# File /opt/hostedtoolcache/Python/3.14.2/x64/lib/python3.14/site-packages/pyaml/tuning_tools/orbit.py:19
#      17 from ..common.element import Element, ElementConfigModel
#      18 from ..common.exception import PyAMLException
# ---> 19 from ..external.pySC.pySC import ResponseMatrix as pySC_ResponseMatrix
#      20 from ..external.pySC.pySC.apps import orbit_correction
#      21 from ..external.pySC_interface import pySCInterface
#
# ModuleNotFoundError: No module named 'pyaml.external.pySC'

# %% [markdown]
# pyaml/tests/config/EBSTune.yaml is an example pyAML yaml configuration file that defines:
# - a 6GeV Storage ring with
#   - 1 array (family) of quadrupoles used for tune correction
#   - 1 tune device
#   - controlled by Tango
#   - simulated with AT
#
# It looks like this:
#
# ```
# type: pyaml.accelerator
# name: sr
# energy: 6e9
# simulators:
#   - type: pyaml.lattice.simulator
#     lattice: sr/lattices/ebs.mat
#     name: design
# controls:
#   - type: tango.pyaml.controlsystem
#     tango_host: ebs-simu-3:10000
#     name: live
#
# data_folder: /data/store
#   arrays:
#     - type: pyaml.arrays.magnet
#       name: QForTune
#       elements:
#         - QD2A-C03
#         - QD2E-C04
#         - QD2A-C05
#         - ...
#   devices:
#   - type: pyaml.magnet.quadrupole
#     name: QD2A-C03
#     model:
#       type: pyaml.magnet.linear_model
#       calibration_factor: 1.002096389
#       crosstalk: 0.99912
#       curve:
#         type: pyaml.configuration.csvcurve
#         file: sr/magnet_models/QD2_strength.csv
#       unit: 1/m
#       powerconverter:
#         type: tango.pyaml.attribute
#         attribute: srmag/vps-qd2/c03-a/current
#         unit: A
#   - ...
#   - ...
#   - ...
#   - type: pyaml.diagnostics.tune_monitor
#     name: BETATRON_TUNE
#     tune_h:
#       type: tango.pyaml.attribute_read_only
#       attribute: srdiag/tune/tune_h
#       unit: mm
#     tune_v:
#       type: tango.pyaml.attribute_read_only
#       attribute: srdiag/tune/tune_v
#       unit: mm
# ```
