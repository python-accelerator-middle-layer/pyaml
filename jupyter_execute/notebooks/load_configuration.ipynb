# %% [markdown]
# # Configuration

# %%
from pyaml.accelerator import Accelerator

SR: Accelerator = Accelerator.load("../../tests/config/EBSTune.yaml")
# Out:
# ---------------------------------------------------------------------------
# PyAMLConfigException                      Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pyaml.accelerator import Accelerator
# ----> 3 SR: Accelerator = Accelerator.load("../../tests/config/EBSTune.yaml")
#
# File /opt/hostedtoolcache/Python/3.14.2/x64/lib/python3.14/site-packages/pyaml/accelerator.py:174, in Accelerator.load(filename, use_fast_loader, ignore_external)
#     172 set_root_folder(rootfolder)
#     173 config_dict = load(os.path.basename(filename), None, use_fast_loader)
# --> 174 return Accelerator.from_dict(config_dict)
#
# File /opt/hostedtoolcache/Python/3.14.2/x64/lib/python3.14/site-packages/pyaml/accelerator.py:144, in Accelerator.from_dict(config_dict, ignore_external)
#     141 if ignore_external:
#     142     # control systems are external, so remove controls field
#     143     config_dict.pop("controls", None)
# --> 144 return Factory.depth_first_build(config_dict, ignore_external)
#
# File /opt/hostedtoolcache/Python/3.14.2/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:175, in PyAMLFactory.depth_first_build(self, d, ignore_external)
#     173 if not key == "__fieldlocations__":
#     174     if isinstance(value, dict) or isinstance(value, list):
# --> 175         obj = self.depth_first_build(value, ignore_external)
#     176         # Replace the inner dict by the object itself
#     177         d[key] = obj
#
# File /opt/hostedtoolcache/Python/3.14.2/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:165, in PyAMLFactory.depth_first_build(self, d, ignore_external)
#     163 for _index, e in enumerate(d):
#     164     if isinstance(e, dict) or isinstance(e, list):
# --> 165         obj = self.depth_first_build(e, ignore_external)
#     166         l.append(obj)
#     167     else:
#
# File /opt/hostedtoolcache/Python/3.14.2/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:180, in PyAMLFactory.depth_first_build(self, d, ignore_external)
#     177                 d[key] = obj
#     179     # We are now on leaf (no nested object), we can construct
# --> 180     return self.build_object(d, ignore_external)
#     182 raise PyAMLConfigException(
#     183     "Unexpected element found. 'dict' or 'list' expected "
#     184     "but got '{d.__class__.__name__}'"
#     185 )
#
# File /opt/hostedtoolcache/Python/3.14.2/x64/lib/python3.14/site-packages/pyaml/configuration/factory.py:95, in PyAMLFactory.build_object(self, d, ignore_external)
#      92 except ModuleNotFoundError as ex:
#      93     if not ignore_external:
#      94         # Discard module not found stack trace
# ---> 95         raise PyAMLConfigException(
#      96             "Module referenced in type cannot be found:"
#      97             + f"'{type_str}' {location_str}"
#      98         ) from None
#      99     else:
#     100         return None
#
# PyAMLConfigException: Module referenced in type cannot be found:'tango.pyaml.controlsystem' /home/runner/work/pyaml/pyaml/tests/config/EBSTune.yaml at line 10, column 5.

# %% [markdown]
# pyaml/tests/config/EBSTune.yaml is an example pyAML yaml configuration file that defines:
# - a 6GeV Storage ring with
#   - 1 array (family) of quadrupoles used for tune correction
#   - 1 tune device
#   - controlled by Tango
#   - simulated with AT
#
# It looks like this:
#
# ```
# type: pyaml.accelerator
# name: sr
# energy: 6e9
# simulators:
#   - type: pyaml.lattice.simulator
#     lattice: sr/lattices/ebs.mat
#     name: design
# controls:
#   - type: tango.pyaml.controlsystem
#     tango_host: ebs-simu-3:10000
#     name: live
#
# data_folder: /data/store
#   arrays:
#     - type: pyaml.arrays.magnet
#       name: QForTune
#       elements:
#         - QD2A-C03
#         - QD2E-C04
#         - QD2A-C05
#         - ...
#   devices:
#   - type: pyaml.magnet.quadrupole
#     name: QD2A-C03
#     model:
#       type: pyaml.magnet.linear_model
#       calibration_factor: 1.002096389
#       crosstalk: 0.99912
#       curve:
#         type: pyaml.configuration.csvcurve
#         file: sr/magnet_models/QD2_strength.csv
#       unit: 1/m
#       powerconverter:
#         type: tango.pyaml.attribute
#         attribute: srmag/vps-qd2/c03-a/current
#         unit: A
#   - ...
#   - ...
#   - ...
#   - type: pyaml.diagnostics.tune_monitor
#     name: BETATRON_TUNE
#     tune_h:
#       type: tango.pyaml.attribute_read_only
#       attribute: srdiag/tune/tune_h
#       unit: mm
#     tune_v:
#       type: tango.pyaml.attribute_read_only
#       attribute: srdiag/tune/tune_v
#       unit: mm
# ```
