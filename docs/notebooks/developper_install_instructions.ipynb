# %% [markdown]
# # prepare
# cd work_dir
#
# deactivate existing python venv
#
# preconditions:
# verify python version > 3.12 ???
# verify github keys, or follow link to set them up
#
# # clone repositories for local development
# git clone https://github.com/python-accelerator-middle-layer/tango-pyaml.git
# git clone https://github.com/python-accelerator-middle-layer/pyaml.git
# git clone https://github.com/python-accelerator-middle-layer/pyaml-cs-oa.git
#
# # create virtual environment
# python -m venv pyaml_venv
# source ./pyaml_venv/bin/activate
#
# pip install --upgrade pip
#
# # install tango-pyaml
# cd tango-pyaml
# pip install -e .
#
# # use latest pyAML version rather than latest release
# pip uninstall accelerator-middle-layer
# cd pyaml
# pip install -e .
#
# # latest ophid asych
# cd ../pyaml-cs-oa/
# pip install -e .
# pip install -e .[dev]    (very very long ~10 min on Simone's laptop)
# pre-commit install
#
# # expected output
# The output of pip list should be similar to:
# (pyaml_venv) macliuzzo:pyaml liuzzo$ pip list
# Package                   Version      Editable project location
# ------------------------- ------------ ----------------------------------------------------------------
# accelerator-middle-layer  0.1.1        /Users/liuzzo/Desktop/pyaml_workshop_dev_instruction/pyaml
# accelerator-toolbox       0.7.1
# aioca                     2.0
# annotated-types           0.7.0
# attrs                     25.4.0
# bluesky                   1.14.6
# cfgv                      3.5.0
# click                     8.3.1
# colorlog                  6.10.1
# compress-pickle           2.1.0
# contourpy                 1.3.3
# cycler                    0.12.1
# distlib                   0.4.0
# docstring_parser          0.17.0
# epicscorelibs             7.0.7.99.1.2
# event-model               1.23.1
# filelock                  3.20.1
# fonttools                 4.61.1
# h5py                      3.15.1
# historydict               1.2.6
# identify                  2.6.15
# importlib_metadata        8.7.0
# importlib_resources       6.5.2
# iniconfig                 2.3.0
# jsonschema                4.25.1
# jsonschema-specifications 2025.9.1
# kiwisolver                1.4.9
# librt                     0.7.4
# lz4                       4.4.5
# matplotlib                3.10.8
# msgpack                   1.1.2
# msgpack-numpy             0.4.8
# mypy                      1.19.1
# mypy_extensions           1.1.0
# nodeenv                   1.9.1
# nose2                     0.15.1
# numpy                     2.3.5
# opentelemetry-api         1.39.1
# ophyd-async               0.14.0
# p4p                       4.2.1
# packaging                 25.0
# pathspec                  0.12.1
# pillow                    12.0.0
# pip                       25.3
# platformdirs              4.5.1
# pluggy                    1.6.0
# ply                       3.11
# pre_commit                4.5.1
# psutil                    7.1.3
# pvxslibs                  1.4.1
# pyaml                     25.7.0
# pyaml-cs-oa               0.0.0        /Users/liuzzo/Desktop/pyaml_workshop_dev_instruction/pyaml-cs-oa
# pydantic                  2.12.5
# pydantic_core             2.41.5
# pydantic-numpy            9.0.1
# Pygments                  2.19.2
# pyparsing                 3.2.5
# pytango                   10.1.1
# pytest                    9.0.2
# python-dateutil           2.9.0.post0
# PyYAML                    6.0.3
# referencing               0.37.0
# rpds-py                   0.30.0
# ruamel.yaml               0.18.0
# ruff                      0.14.9
# scanspec                  0.9.0
# scipy                     1.16.3
# semver                    3.0.4
# setuptools                80.9.0
# setuptools_dso            2.12.2
# six                       1.17.0
# stamina                   25.2.0
# tango-pyaml               0.3.1        /Users/liuzzo/Desktop/pyaml_workshop_dev_instruction/tango-pyaml
# tenacity                  9.1.2
# toolz                     1.1.0
# tqdm                      4.67.1
# typing_extensions         4.15.0
# typing-inspection         0.4.2
# velocity-profile          1.0.0
# virtualenv                20.35.4
# zipp                      3.23.0
#
# ## test that the installation is working correctly by running a pyAML example script
# python ./pyaml/examples/ESRF_tune_example/esrf_tune_example.py \\
#
#
# ## example of development of pyaml documentation
#
# cd pyaml
#
# # create a new branch
# git checkout -b doc-devnotebook
#
# # push the branch to remote
# git push -u origin doc-devnotebook
#
# # modify something or add a file
# edit ./pyaml/docs/notebooks/developper_install_instructions.ipynb
# save
#
# # add file to git revision
# git add docs/notebooks/developper_install_instructions.ipynb
#
# # test your code developments locally (in this example, build teh documentation locally)
# pip install sphinx
# pip install myst_nb
# pip install pydata_sphinx_theme
# python -m sphinx -b html docs ./docs/_build -d ./docs/_build
#
# # commit change
# git commit ./docs/notebooks/developper_install_instructions.ipynb -m'some draft notes'
#
# # push to remote
# git push
#
# ## open a pull request to accept your change:
# in a browser navigate to: https://github.com/python-accelerator-middle-layer/pyaml
# click on "compare and pull request"
# Add some description and click on Create pull request.
#
# The pull request page will open
# Add reviewers to your pull request: in order to be approved, 2 positive reviews are needed.
